# %%
import os
import random
import numpy as np
import pandas as pd
from tqdm import tqdm
import matplotlib.pyplot as plt
from datetime import date, timedelta

from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import mean_squared_error

from scipy.stats import skew, kurtosis

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

from tensorflow.keras.layers import *
from tensorflow.keras.models import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.callbacks import *
from tensorflow.keras import backend as K

# %% [markdown]
# Code below is based on
#
# - https://github.com/cerlymarco/MEDIUM_NoteBook/blob/master/Graph_TimeSeries_Forecasting/Graph_TimeSeries_Forecasting.ipynb
# - the above comes from https://towardsdatascience.com/time-series-forecasting-with-graph-convolutional-neural-network-7ffb3b70afcf
# - https://github.com/danielegrattarola/spektral/blob/master/examples/node_prediction/citation_gat.py

# %%
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import activations

# %%
from spektral_utilities import *
from spektral_gcn import GraphConv

from spektral.layers import GCNConv

# %%
### UTILITY FUNCTIONS FOR FEATURE ENGINEERING ###

sequence_length = 24 # play with this

def get_timespan(df, today, days):    
    df = df[pd.date_range(today - timedelta(days=days), 
            periods=days, freq='D')] # day - n_days <= dates < day    
    return df

def create_features(df, today, seq_len):
    
    all_sequence = get_timespan(df, today, seq_len).values
    
    group_store = all_sequence.reshape((-1, 10, seq_len))
    
    store_corr = np.stack([np.corrcoef(i) for i in group_store], axis=0)
    
    store_features = np.stack([
              group_store.mean(axis=2),
              group_store[:,:,int(sequence_length/2):].mean(axis=2),
              group_store.std(axis=2),
              group_store[:,:,int(sequence_length/2):].std(axis=2),
              skew(group_store, axis=2),
              kurtosis(group_store, axis=2),
              np.apply_along_axis(lambda x: np.polyfit(np.arange(0, sequence_length), x, 1)[0], 2, group_store)
            ], axis=1)
    
    group_store = np.transpose(group_store, (0,2,1))
    store_features = np.transpose(store_features, (0,2,1))
    
    return group_store, store_corr, store_features

def create_label(df, today):
    
    y = df[today].values
    
    return y.reshape((-1, 10))

def set_seed(seed):
    
    tf.random.set_seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    random.seed(seed)

# %%
### READ DATA ###

df = pd.read_csv('../dataset/SalesGNNTimeSeries/sales_train.csv.zip')
df['date'] = pd.to_datetime(df['date'])

print(df.shape)
df.head()
# Out:
# (913000, 4)
#         date  store  item  sales
# 0 2013-01-01      1     1     13
# 1 2013-01-02      1     1     11
# 2 2013-01-03      1     1     14
# 3 2013-01-04      1     1     13
# 4 2013-01-05      1     1     10

# %%
### SWITCH DATA FROM VERTICAL TO HORIZONTAL FORMAT ###

unstaked_df = df.copy()
unstaked_df['id'] = df['item'].astype(str)+'_'+df['store'].astype(str)
unstaked_df.set_index(['id','date'], inplace=True)
unstaked_df.drop(['store','item'], axis=1, inplace=True)
unstaked_df = unstaked_df.astype(float).unstack()
unstaked_df.columns = unstaked_df.columns.get_level_values(1)

print(unstaked_df.shape)
unstaked_df.head()
# Out:
# (500, 1826)
# date   2013-01-01  2013-01-02  2013-01-03  2013-01-04  2013-01-05  2013-01-06  \
# id
# 10_1         37.0        34.0        32.0        45.0        35.0        54.0
# 10_10        45.0        50.0        53.0        51.0        54.0        54.0
# 10_2         51.0        56.0        46.0        56.0        53.0        68.0
# 10_3         38.0        60.0        50.0        46.0        46.0        52.0
# 10_4         30.0        29.0        37.0        45.0        52.0        58.0
#
# date   2013-01-07  2013-01-08  2013-01-09  2013-01-10  ...  2017-12-22  \
# id                                                     ...
# 10_1         37.0        37.0        32.0        36.0  ...        60.0
# 10_10        54.0        40.0        50.0        53.0  ...        64.0
# 10_2         37.0        47.0        65.0        61.0  ...        86.0
# 10_3         40.0        41.0        32.0        38.0  ...        83.0
# 10_4         29.0        44.0        53.0        39.0  ...        75.0
#
# date   2017-12-23  2017-12-24  2017-12-25  2017-12-26  2017-12-27  2017-12-28  \
# id
# 10_1         67.0        88.0        42.0        50.0        55.0        63.0
# 10_10        74.0        66.0        61.0        53.0        72.0        81.0
# 10_2        114.0        84.0        66.0        69.0        63.0        78.0
# 10_3         71.0       101.0        45.0        61.0        51.0        56.0
# 10_4         64.0        86.0        56.0        54.0        57.0        53.0
#
# date   2017-12-29  2017-12-30  2017-12-31
# id
# 10_1         56.0        78.0        74.0
# 10_10        69.0        86.0        67.0
# 10_2         76.0        77.0       116.0
# 10_3         61.0        72.0        68.0
# 10_4         65.0        74.0        69.0
#
# [5 rows x 1826 columns]

# %%
### PLOT A SEQUENCE OF SALES FOR ITEM 10 IN ALL STORES ###

sequence = get_timespan(unstaked_df, date(2017,11,1), 30)
sequence.head(10).T.plot(figsize=(14,5))
plt.ylabel('sales')
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))

# %%
### DEFINE TRAIN, VALID, TEST DATES ###

train_date = date(2013, 1, 1)
valid_date = date(2015, 1, 1)
test_date = date(2016, 1, 1)

X_seq, X_cor, X_feat, y = [], [], [], []

for d in tqdm(pd.date_range(train_date+timedelta(days=sequence_length), valid_date)):
    seq_, corr_, feat_ = create_features(unstaked_df, d, sequence_length)
    y_ = create_label(unstaked_df, d)
    X_seq.append(seq_), X_cor.append(corr_), X_feat.append(feat_), y.append(y_)
    
X_train_seq = np.concatenate(X_seq, axis=0).astype('float16')
X_train_cor = np.concatenate(X_cor, axis=0).astype('float16')
X_train_feat = np.concatenate(X_feat, axis=0).astype('float16')
y_train = np.concatenate(y, axis=0).astype('float16')

print(X_train_seq.shape, X_train_cor.shape, X_train_feat.shape, y_train.shape)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████| 707/707 [00:26<00:00, 26.43it/s]
# (35350, 24, 10) (35350, 10, 10) (35350, 10, 7) (35350, 10)

# %%
### CREATE VALID FEATURES ###

X_seq, X_cor, X_feat, y = [], [], [], []

for d in tqdm(pd.date_range(valid_date+timedelta(days=sequence_length), test_date)):
    seq_, corr_, feat_ = create_features(unstaked_df, d, sequence_length)
    y_ = create_label(unstaked_df, d)
    X_seq.append(seq_), X_cor.append(corr_), X_feat.append(feat_), y.append(y_)
    
X_valid_seq = np.concatenate(X_seq, axis=0).astype('float16')
X_valid_cor = np.concatenate(X_cor, axis=0).astype('float16')
X_valid_feat = np.concatenate(X_feat, axis=0).astype('float16')
y_valid = np.concatenate(y, axis=0).astype('float16')

print(X_valid_seq.shape, X_valid_cor.shape, X_valid_feat.shape, y_valid.shape)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████| 342/342 [00:11<00:00, 28.90it/s]
# (17100, 24, 10) (17100, 10, 10) (17100, 10, 7) (17100, 10)

# %%
X_seq, X_cor, X_feat, y = [], [], [], []

for d in tqdm(pd.date_range(test_date+timedelta(days=sequence_length), date(2016,12,31))):
    seq_, corr_, feat_ = create_features(unstaked_df, d, sequence_length)
    y_ = create_label(unstaked_df, d)
    X_seq.append(seq_), X_cor.append(corr_), X_feat.append(feat_), y.append(y_)
    
X_test_seq = np.concatenate(X_seq, axis=0).astype('float16')
X_test_cor = np.concatenate(X_cor, axis=0).astype('float16')
X_test_feat = np.concatenate(X_feat, axis=0).astype('float16')
y_test = np.concatenate(y, axis=0).astype('float16')

print(X_test_seq.shape, X_test_cor.shape, X_test_feat.shape, y_test.shape)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████| 342/342 [00:12<00:00, 27.72it/s]
# (17100, 24, 10) (17100, 10, 10) (17100, 10, 7) (17100, 10)

# %%
# Scale sequences
scaling_type = 'minmax'

if scaling_type == 'standard':
    scaler_seq = StandardScaler()
    scaler_feat = StandardScaler()
elif scaling_type == 'minmax':
    scaler_seq = MinMaxScaler()
    scaler_feat = MinMaxScaler()

X_train_seq = scaler_seq.fit_transform(X_train_seq.reshape(-1,10)).reshape(X_train_seq.shape)
X_valid_seq = scaler_seq.transform(X_valid_seq.reshape(-1,10)).reshape(X_valid_seq.shape)
X_test_seq = scaler_seq.transform(X_test_seq.reshape(-1,10)).reshape(X_test_seq.shape)

y_train = scaler_seq.transform(y_train)
y_valid = scaler_seq.transform(y_valid)
y_test = scaler_seq.transform(y_test)

X_train_feat = scaler_feat.fit_transform(X_train_feat.reshape(-1,10)).reshape(X_train_feat.shape)
X_valid_feat = scaler_feat.transform(X_valid_feat.reshape(-1,10)).reshape(X_valid_feat.shape)
X_test_feat = scaler_feat.transform(X_test_feat.reshape(-1,10)).reshape(X_test_feat.shape)

# %%
(X_train_seq.reshape(-1,10)).shape
# Out:
# (848400, 10)

# %%
y_train.shape
# Out:
# (35350, 10)

# %%
X_train_feat.shape
# Out:
# (34150, 10, 7)

# %%
X_train_seq.shape
# Out:
# (34150, 48, 10)

# %%
np.save('../features/SalesGNNTimeSeries/X_train_feat.npy', X_train_feat)
np.save('../features/SalesGNNTimeSeries/X_valid_feat.npy', X_valid_feat)
np.save('../features/SalesGNNTimeSeries/X_test_feat.npy', X_test_feat)

np.save('../features/SalesGNNTimeSeries/X_train_seq.npy', X_train_seq)
np.save('../features/SalesGNNTimeSeries/X_valid_seq.npy', X_valid_seq)
np.save('../features/SalesGNNTimeSeries/X_test_seq.npy', X_test_seq)

np.save('../features/SalesGNNTimeSeries/y_train.npy', y_train)
np.save('../features/SalesGNNTimeSeries/y_valid.npy', y_valid)
np.save('../features/SalesGNNTimeSeries/y_test.npy', y_test)

# %%
### OBTAIN LAPLACIANS FROM CORRELATIONS ###

X_train_lap = localpooling_filter(1 - np.abs(X_train_cor))
X_valid_lap = localpooling_filter(1 - np.abs(X_valid_cor))
X_test_lap = localpooling_filter(1 - np.abs(X_test_cor))

# %%
def get_model():
    set_seed(33)

    opt = Adam(lr=0.001)

    inp_seq = Input((sequence_length, 10))
    inp_lap = Input((10, 10))
    inp_feat = Input((10, X_train_feat.shape[-1]))

    x = GCNConv(32, activation='relu')([inp_feat, inp_lap])
    x = GCNConv(16, activation='relu')([x, inp_lap])
    x = Flatten()(x)

    xx = LSTM(128, activation='relu', return_sequences=True)(inp_seq)
    xx = LSTM(32, activation='relu')(xx)

    x = Concatenate()([x,xx])
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = Dense(128, activation='relu')(x)
    x = Dense(32, activation='relu')(x)
    x = Dropout(0.3)(x)
    out = Dense(1)(x)

    model = Model([inp_seq, inp_lap, inp_feat], out)
    model.compile(optimizer=opt, loss='mse', 
                  metrics=[tf.keras.metrics.RootMeanSquaredError()])

    return model

# %%
def get_encoder():
    latent_dim = 2

    inp_seq = keras.Input((sequence_length, 10))
    inp_lap = keras.Input((10, 10))
    inp_feat = keras.Input((10, X_train_feat.shape[-1]))

    encoder_inputs = [inp_seq, inp_lap, inp_feat]

    x = GCNConv(32, activation='relu')([inp_feat, inp_lap])
    x = GCNConv(16, activation='relu')([x, inp_lap])
    x = layers.Flatten()(x)

    xx = LSTM(128, activation='relu', return_sequences=True)(inp_seq)
    xx = LSTM(32, activation='relu')(xx)

    x = Concatenate()([x,xx])
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = layers.Dense(128, activation='relu')(x)
    x = layers.Dense(32, activation='relu')(x)
    x = Dropout(0.3)(x)

    z_mean = layers.Dense(latent_dim, name="z_mean")(x)
    z_log_var = layers.Dense(latent_dim, name="z_log_var")(x)
    z = Sampling()([z_mean, z_log_var])
    encoder = keras.Model(encoder_inputs, [z_mean, z_log_var, z], name="encoder")
    return encoder

encoder = get_encoder()
encoder.summary()
# Out:
# Model: "encoder"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_80 (InputLayer)          [(None, 10, 7)]      0           []
#
#  input_79 (InputLayer)          [(None, 10, 10)]     0           []
#
#  gcn_conv_61 (GCNConv)          (None, 10, 32)       256         ['input_80[0][0]',
#                                                                   'input_79[0][0]']
#
#  input_78 (InputLayer)          [(None, 14, 10)]     0           []
#
#  gcn_conv_62 (GCNConv)          (None, 10, 16)       528         ['gcn_conv_61[0][0]',
#                                                                   'input_79[0][0]']
#
#  lstm_80 (LSTM)                 (None, 14, 128)      71168       ['input_78[0][0]']
#
#  flatten_21 (Flatten)           (None, 160)          0           ['gcn_conv_62[0][0]']
#
#  lstm_81 (LSTM)                 (None, 32)           20608       ['lstm_80[0][0]']
#
#  concatenate_28 (Concatenate)   (None, 192)          0           ['flatten_21[0][0]',
#                                                                   'lstm_81[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 192)         768         ['concatenate_28[0][0]']
#  ormalization)
#
#  dropout_42 (Dropout)           (None, 192)          0           ['batch_normalization_21[0][0]']
#
#  dense_99 (Dense)               (None, 128)          24704       ['dropout_42[0][0]']
#
#  dense_100 (Dense)              (None, 32)           4128        ['dense_99[0][0]']
#
#  dropout_43 (Dropout)           (None, 32)           0           ['dense_100[0][0]']
#
#  z_mean (Dense)                 (None, 2)            66          ['dropout_43[0][0]']
#
#  z_log_var (Dense)              (None, 2)            66          ['dropout_43[0][0]']
#
#  sampling_3 (Sampling)          (None, 2)            0           ['z_mean[0][0]',
#                                                                   'z_log_var[0][0]']
#
# ==================================================================================================
# Total params: 122,292
# Trainable params: 121,908
# Non-trainable params: 384
# __________________________________________________________________________________________________

# %%
inp_seq.shape
# Out:
# TensorShape([None, 14, 10])

# %%
# GCNConv
#|  **Input**
#|  
#|  - Node features of shape `([batch], n_nodes, n_node_features)`;
#|  - Modified Laplacian of shape `([batch], n_nodes, n_nodes)`; can be computed with
#|  `spektral.utils.convolution.gcn_filter`.
#|  
#|  **Output**
#|  
#|  - Node features with the same shape as the input, but with the last
#|  dimension changed to `channels`.

def get_decoder():
    #inp_lap_out = keras.Input((10, 10))

    latent_inputs = keras.Input(shape=(latent_dim,))

    #concatenated_input = layers.concatenate([latent_inputs, inp_lap])

    x = layers.Dense(28, activation="relu")(latent_inputs)

    x_lstm = layers.Reshape((14, 2))(x)

    x_lstm = LSTM(10, activation='relu', return_sequences=True)(x_lstm)
    #x_lstm = LSTM(128, activation='relu', return_sequences=True)(x_lstm)

    x_gnn = layers.Dense(160, activation="relu")(latent_inputs)
    x_lap = layers.Dense(100, activation="relu")(latent_inputs)
    
    x_gnn = layers.Reshape((10, 16))(x_gnn)
    x_lap = layers.Reshape((10, 10))(x_lap)
    
    x_gnn = GCNConv(16, activation='relu')([x_gnn, x_lap])
    x_gnn = GCNConv(7, activation='relu')([x_gnn, x_lap])
    decoder_outputs = [x_lstm, x_lap, x_gnn]
    decoder = keras.Model([latent_inputs], decoder_outputs, name="decoder")
    #decoder_gnn = keras.Model([latent_inputs], [x_gnn], name="decoder")
    return decoder

decoder = get_decoder()
decoder.summary()
# Out:
# Model: "decoder"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_83 (InputLayer)          [(None, 2)]          0           []
#
#  dense_107 (Dense)              (None, 100)          300         ['input_83[0][0]']
#
#  dense_106 (Dense)              (None, 160)          480         ['input_83[0][0]']
#
#  dense_105 (Dense)              (None, 28)           84          ['input_83[0][0]']
#
#  reshape_46 (Reshape)           (None, 10, 10)       0           ['dense_107[0][0]']
#
#  reshape_45 (Reshape)           (None, 10, 16)       0           ['dense_106[0][0]']
#
#  reshape_44 (Reshape)           (None, 14, 2)        0           ['dense_105[0][0]']
#
#  gcn_conv_65 (GCNConv)          (None, 10, 16)       272         ['reshape_45[0][0]',
#                                                                   'reshape_46[0][0]']
#
#  lstm_84 (LSTM)                 (None, 14, 10)       520         ['reshape_44[0][0]']
#
#  gcn_conv_66 (GCNConv)          (None, 10, 7)        119         ['gcn_conv_65[0][0]',
#                                                                   'reshape_46[0][0]']
#
# ==================================================================================================
# Total params: 1,775
# Trainable params: 1,775
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
decoder.compute_output_shape([(100, 2)])
# Out:
# [TensorShape([100, 14, 10]),
#  TensorShape([100, 10, 10]),
#  TensorShape([100, 10, 7])]

# %%
encoder.input_shape
# Out:
# [(None, 14, 10), (None, 10, 10), (None, 10, 7)]

# %%
tuple(list(inp_seq.shape))
# Out:
# (None, 14, 10)

# %%
inp_lap.shape
# Out:
# TensorShape([None, 10, 10])

# %%
inp_feat.shape
# Out:
# TensorShape([None, 10, 7])

# %%
class Sampling(layers.Layer):
    """Uses (z_mean, z_log_var) to sample z, the vector encoding a digit."""

    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = tf.shape(z_mean)[0]
        dim = tf.shape(z_mean)[1]
        epsilon = tf.keras.backend.random_normal(shape=(batch, dim))
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon
    
class Encoder(layers.Layer):
    """Maps MNIST digits to a triplet (z_mean, z_log_var, z)."""

    def __init__(self, ts_sequence_length, num_ts_features, latent_dim=2, intermediate_dim=64, name="encoder", **kwargs):
        super(Encoder, self).__init__(name=name, **kwargs)
        #latent_dim = 2

        self.ts_sequence_length = ts_sequence_length
        self.num_ts_features = num_ts_features
        self.inp_seq = keras.Input((self.ts_sequence_length, 10))
        self.inp_lap = keras.Input((10, 10))
        self.inp_feat = keras.Input((10, self.num_ts_features))

        self.encoder_inputs = [self.inp_seq, self.inp_lap, self.inp_feat]
        
        self.gcn_conv1 = GCNConv(32, activation=layers.LeakyReLU(alpha=0.01))
        self.gcn_conv2 = GCNConv(16, activation=layers.LeakyReLU(alpha=0.01))
        
        self.flatten_layer = layers.Flatten()
        
        self.lstm1 = LSTM(128, activation=layers.LeakyReLU(alpha=0.01), return_sequences=True)
        self.lstm2 = LSTM(32, activation=layers.LeakyReLU(alpha=0.01))
        
        self.concat_layer = Concatenate()
        self.batch_norm_layer = BatchNormalization()
        
        self.dropout1 = Dropout(0.1)
        self.fully_connected1 = layers.Dense(intermediate_dim, activation=layers.LeakyReLU(alpha=0.01))
        self.dropout2 = Dropout(0.1)
        
        self.dense_mean = layers.Dense(latent_dim, name="z_mean")
        self.dense_log_var = layers.Dense(latent_dim, name="z_log_var")
        self.sampling = Sampling()

    def call(self, inputs):
        self.inp_seq = inputs[0]
        self.inp_feat = inputs[2]
        self.inp_lap = inputs[1]
        
        x = self.gcn_conv1([self.inp_feat, self.inp_lap])
        x = self.gcn_conv2([x, self.inp_lap])
        x = self.flatten_layer(x)

        xx = self.lstm1(self.inp_seq)
        xx = self.lstm2(xx)

        x = self.concat_layer([x,xx])
        x = self.batch_norm_layer(x)
        x = self.dropout1(x)
        x = self.fully_connected1(x)
        x = self.dropout2(x)

        z_mean = self.dense_mean(x)
        z_log_var = self.dense_log_var(x)
        z = self.sampling((z_mean, z_log_var))

        return z_mean, z_log_var, z


class Decoder(layers.Layer):
    """Converts z, the encoded digit vector, back into a readable digit."""

    def __init__(self, original_dim, latent_dim=2, intermediate_dim=64, name="decoder", **kwargs):
        super(Decoder, self).__init__(name=name, **kwargs)        
        self.latent_inputs = keras.Input(shape=(latent_dim,))
        
        self.fully_connected_lstm = layers.Dense(28, activation=layers.LeakyReLU(alpha=0.01))
        self.reshape_layer_lstm = layers.Reshape((14, 2))
        self.lstm_layer1 = LSTM(10, activation=layers.LeakyReLU(alpha=0.01), return_sequences=True)
        self.lstm_layer2 = LSTM(128, activation=layers.LeakyReLU(alpha=0.01), return_sequences=True)
        
        self.fully_connected_gcn1 = layers.Dense(160, activation=layers.LeakyReLU(alpha=0.01))
        self.fully_connected_lap1 = layers.Dense(100, activation=layers.LeakyReLU(alpha=0.01))
        
        self.reshape_layer_gcn = layers.Reshape((10, 16))
        self.reshape_layer_lap = layers.Reshape((10, 10))
        
        self.gcn_layer1 = GCNConv(16, activation=layers.LeakyReLU(alpha=0.01))
        self.gcn_layer2 = GCNConv(7, activation=layers.LeakyReLU(alpha=0.01))

    def call(self, inputs):
        x_lstm = self.fully_connected_lstm(inputs)
        x_lstm = self.reshape_layer_lstm(x_lstm)

        x_lstm = self.lstm_layer1(x_lstm)
        #x_lstm = self.lstm_layer2(x_lstm)

        x_lap = self.fully_connected_lap1(inputs)
        x_lap = self.reshape_layer_lap(x_lap)
        
        x_gnn = self.fully_connected_gcn1(inputs)
        x_gnn = self.reshape_layer_gcn(x_gnn)
        x_gnn = self.gcn_layer1([x_gnn, x_lap])
        x_gnn = self.gcn_layer2([x_gnn, x_lap])
        return x_lstm, x_lap, x_gnn

class VAE(keras.Model):
    def __init__(self, 
                 original_dim,
                 ts_sequence_length,
                 num_ts_features,
                 intermediate_dim=64,
                 latent_dim=2,
                 name="variational-autoencoder",
                 **kwargs):
        super(VAE, self).__init__(name=name, **kwargs)
        self.original_dim = original_dim
        self.encoder = Encoder(ts_sequence_length=ts_sequence_length, num_ts_features=num_ts_features, latent_dim=latent_dim, intermediate_dim=intermediate_dim)
        self.decoder = Decoder(original_dim, latent_dim=latent_dim, intermediate_dim=intermediate_dim)
        #self.total_loss_tracker = keras.metrics.Mean(name="total_loss")
        #self.reconstruction_loss_tracker = keras.metrics.Mean(
        #    name="reconstruction_loss"
        #)
        #self.kl_loss_tracker = keras.metrics.Mean(name="kl_loss")

    #@property
    #def metrics(self):
    #    return [
    #        self.total_loss_tracker,
    #        self.reconstruction_loss_tracker,
    #        self.kl_loss_tracker,
    #    ]

    def call(self, inputs):
        #with tf.GradientTape() as tape:
        z_mean, z_log_var, z = self.encoder(inputs)
        #print(data[0][0])
        reconstruction = self.decoder(z)
        #print(reconstruction[0])
        #reconstruction_loss = tf.reduce_mean(
        #    tf.reduce_sum(
        #        keras.losses.binary_crossentropy(data[0][0], reconstruction[0]), axis=(1)
        #    )
        #)
        #reconstruction_loss += tf.reduce_mean(
        #    tf.reduce_sum(
        #        keras.losses.binary_crossentropy(data[0][1], reconstruction[1]), axis=(1)
        #    )
        #)
        #reconstruction_loss += tf.reduce_mean(
        #    tf.reduce_sum(
        #        keras.losses.binary_crossentropy(data[0][2], reconstruction[2]), axis=(1)
        #    )
        #)
        #kl_loss = -0.5 * (1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var))
        #kl_loss = tf.reduce_mean(tf.reduce_sum(kl_loss, axis=1))
        #total_loss = reconstruction_loss + kl_loss

        # Add KL divergence regularization loss.
        kl_loss = -0.5 * tf.reduce_mean(
            z_log_var - tf.square(z_mean) - tf.exp(z_log_var) + 1
        )
        #grads = tape.gradient(total_loss, self.trainable_weights)
        #self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
        #self.total_loss_tracker.update_state(total_loss)
        #self.reconstruction_loss_tracker.update_state(reconstruction_loss)
        #self.kl_loss_tracker.update_state(kl_loss)

        self.add_loss(kl_loss)
        return reconstruction

# %%
y_true = np.array([[0, 1], [0, 0]])
y_true2 = np.array([[0, 1, 2], [0, 0, 2]])

y_pred = np.array([[-18.6, 0.51], [2.94, -12.8]])
y_pred2 = np.array([[-18.6, 0.51, 0.67], [2.94, -12.8, 0.89]])

# Using default 'auto'/'sum_over_batch_size' reduction type.
bce = tf.keras.losses.BinaryCrossentropy(from_logits=True)
bce([y_true, y_true2], [y_pred, y_pred2]).numpy()

# %%
X_train_seq.shape
# Out:
# (35850, 14, 10)

# %%
def get_model():
    vae = VAE(original_dim = 2, latent_dim = 32, ts_sequence_length=sequence_length, num_ts_features=7)
    vae.compile(optimizer=keras.optimizers.Adam(0.001), loss='mse', 
                      metrics=[tf.keras.metrics.RootMeanSquaredError()])
    return vae

# %%
X_valid_seq.shape
# Out:
# (17600, 14, 10)

# %%
### TRAIN A MODEL FOR EACH STORES USING ALL THE DATA AVAILALBE FROM OTHER STORES ###

es = EarlyStopping(patience=5, verbose=1, min_delta=0.001, monitor='val_loss', mode='auto', restore_best_weights=True)

model = get_model()
#print(model.summary())
model.fit([X_train_seq, X_train_lap, X_train_feat], [X_train_seq, X_train_lap, X_train_feat], epochs=100, batch_size=256, 
          validation_data=([X_valid_seq, X_valid_lap, X_valid_feat], [X_valid_seq, X_valid_lap, X_valid_feat]), callbacks=[es], verbose=2)

pred_valid_all = model.predict([X_valid_seq, X_valid_lap, X_valid_feat])
pred_test_all = model.predict([X_test_seq, X_test_lap, X_test_feat])


pred_valid_all_recons = scaler_seq.inverse_transform(pred_valid_all[0].reshape(-1,10)).reshape(pred_valid_all[0].shape)
#reverse_valid = scaler_seq.inverse_transform(y_valid)
pred_test_all_recons = scaler_seq.inverse_transform(pred_test_all[0].reshape(-1,10)).reshape(pred_test_all[0].shape)
#reverse_test = scaler_seq.inverse_transform(y_test)
# Out:
# Epoch 1/100
# 141/141 - 21s - loss: 2.2079 - output_1_loss: 0.9244 - output_2_loss: 0.1294 - output_3_loss: 0.9832 - output_1_root_mean_squared_error: 0.9615 - output_2_root_mean_squared_error: 0.3597 - output_3_root_mean_squared_error: 0.9916 - val_loss: 2.1950 - val_output_1_loss: 1.1192 - val_output_2_loss: 0.1284 - val_output_3_loss: 0.9194 - val_output_1_root_mean_squared_error: 1.0579 - val_output_2_root_mean_squared_error: 0.3584 - val_output_3_root_mean_squared_error: 0.9588 - 21s/epoch - 149ms/step
# Epoch 2/100
# 141/141 - 13s - loss: 1.3922 - output_1_loss: 0.6904 - output_2_loss: 0.0985 - output_3_loss: 0.4456 - output_1_root_mean_squared_error: 0.8309 - output_2_root_mean_squared_error: 0.3138 - output_3_root_mean_squared_error: 0.6675 - val_loss: 1.5319 - val_output_1_loss: 0.8317 - val_output_2_loss: 0.1035 - val_output_3_loss: 0.5430 - val_output_1_root_mean_squared_error: 0.9120 - val_output_2_root_mean_squared_error: 0.3217 - val_output_3_root_mean_squared_error: 0.7369 - 13s/epoch - 92ms/step
# 141/141 - 17s - loss: 0.6260 - output_1_loss: 0.5439 - output_2_loss: 0.0044 - output_3_loss: 0.0239 - output_1_root_mean_squared_error: 0.7375 - output_2_root_mean_squared_error: 0.0666 - output_3_root_mean_squared_error: 0.1545 - val_loss: 0.5692 - val_output_1_loss: 0.4838 - val_output_2_loss: 0.0046 - val_output_3_loss: 0.0236 - val_output_1_root_mean_squared_error: 0.6956 - val_output_2_root_mean_squared_error: 0.0681 - val_output_3_root_mean_squared_error: 0.1535 - 17s/epoch - 124ms/step
# Epoch 52/100
# 141/141 - 18s - loss: 0.6261 - output_1_loss: 0.5440 - output_2_loss: 0.0045 - output_3_loss: 0.0238 - output_1_root_mean_squared_error: 0.7376 - output_2_root_mean_squared_error: 0.0669 - output_3_root_mean_squared_error: 0.1543 - val_loss: 0.5706 - val_output_1_loss: 0.4827 - val_output_2_loss: 0.0047 - val_output_3_loss: 0.0244 - val_output_1_root_mean_squared_error: 0.6947 - val_output_2_root_mean_squared_error: 0.0684 - val_output_3_root_mean_squared_error: 0.1563 - 18s/epoch - 125ms/step
# Epoch 53/100
# 141/141 - 17s - loss: 0.6256 - output_1_loss: 0.5437 - output_2_loss: 0.0045 - output_3_loss: 0.0232 - output_1_root_mean_squared_error: 0.7374 - output_2_root_mean_squared_error: 0.0672 - output_3_root_mean_squared_error: 0.1523 - val_loss: 0.5721 - val_output_1_loss: 0.4822 - val_output_2_loss: 0.0047 - val_output_3_loss: 0.0263 - val_output_1_root_mean_squared_error: 0.6944 - val_output_2_root_mean_squared_error: 0.0685 - val_output_3_root_mean_squared_error: 0.1621 - 17s/epoch - 121ms/step
# Epoch 54/100
# 141/141 - 17s - loss: 0.6255 - output_1_loss: 0.5439 - output_2_loss: 0.0045 - output_3_loss: 0.0232 - output_1_root_mean_squared_error: 0.7375 - output_2_root_mean_squared_error: 0.0673 - output_3_root_mean_squared_error: 0.1522 - val_loss: 0.5673 - val_output_1_loss: 0.4801 - val_output_2_loss: 0.0048 - val_output_3_loss: 0.0222 - val_output_1_root_mean_squared_error: 0.6929 - val_output_2_root_mean_squared_error: 0.0691 - val_output_3_root_mean_squared_error: 0.1490 - 17s/epoch - 119ms/step
# Epoch 55/100
# Restoring model weights from the end of the best epoch: 50.
# 141/141 - 17s - loss: 0.6245 - output_1_loss: 0.5436 - output_2_loss: 0.0045 - output_3_loss: 0.0223 - output_1_root_mean_squared_error: 0.7373 - output_2_root_mean_squared_error: 0.0671 - output_3_root_mean_squared_error: 0.1492 - val_loss: 0.5695 - val_output_1_loss: 0.4815 - val_output_2_loss: 0.0048 - val_output_3_loss: 0.0224 - val_output_1_root_mean_squared_error: 0.6939 - val_output_2_root_mean_squared_error: 0.0695 - val_output_3_root_mean_squared_error: 0.1496 - 17s/epoch - 120ms/step
# Epoch 55: early stopping

# %%
pred_valid_all[0].shape
# Out:
# (17600, 14, 10)

# %%
pred_valid_all_recons = np.resize(pred_valid_all_recons, (np.prod(pred_valid_all_recons.shape[:2]), pred_valid_all_recons.shape[-1]))
pred_valid_all_recons.shape
# Out:
# (246400, 10)

# %%
pred_test_all_recons = np.resize(pred_test_all_recons, (np.prod(pred_test_all_recons.shape[:2]), pred_test_all_recons.shape[-1]))
pred_test_all_recons.shape
# Out:
# (246400, 10)

# %%
X_valid_seq_reshaped = scaler_seq.inverse_transform(X_valid_seq.reshape(-1,10)).reshape(X_valid_seq.shape)

X_valid_seq_reshaped = np.resize(X_valid_seq_reshaped, (np.prod(X_valid_seq_reshaped.shape[:2]), X_valid_seq_reshaped.shape[-1]))
X_valid_seq_reshaped.shape
# Out:
# (246400, 10)

# %%
X_test_seq_reshaped = scaler_seq.inverse_transform(X_test_seq.reshape(-1,10)).reshape(X_test_seq.shape)

X_test_seq_reshaped = np.resize(X_test_seq_reshaped, (np.prod(X_test_seq_reshaped.shape[:2]), X_test_seq_reshaped.shape[-1]))
X_test_seq_reshaped.shape
# Out:
# (246400, 10)

# %%
error = {}

for store in range(10):
    
    error[store] = np.sqrt(mean_squared_error(reverse_test[:,store], pred_test_all[:,store]))

# %%
### PLOT RMSE ###

plt.figure(figsize=(14,5))
plt.bar(range(10), error.values())
plt.xticks(range(10), ['store_'+str(s) for s in range(10)])
plt.ylabel('error')
np.set_printoptions(False)

# %%
fig = plt.figure(figsize=(14,5))
plt.plot(pred_test_all_recons[:2000, 5])
plt.plot(X_test_seq_reshaped[:2000, 5])

plt.ylabel('sales')
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
fig = plt.figure(figsize=(14,5))
plt.plot(pred_valid_all_recons[:200, 5])
plt.plot(X_valid_seq_reshaped[:200, 5])

plt.ylabel('sales')
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
class Encoder(layers.Layer):
    """Maps MNIST digits to a triplet (z_mean, z_log_var, z)."""

    def __init__(self, ts_sequence_length, num_ts_features, latent_dim=2, intermediate_dim=64, name="encoder", activation_func=tf.nn.tanh, **kwargs):
        super(Encoder, self).__init__(name=name, **kwargs)
        #latent_dim = 2

        self.ts_sequence_length = ts_sequence_length
        self.num_ts_features = num_ts_features
        self.inp_seq = keras.Input((self.ts_sequence_length, 10))
        self.inp_lap = keras.Input((10, 10))
        self.inp_feat = keras.Input((10, self.num_ts_features))

        self.encoder_inputs = [self.inp_seq, self.inp_lap, self.inp_feat]
        
        self.gcn_conv1 = GCNConv(32, activation=activation_func)
        
        self.flatten_layer = layers.Flatten()
        
        self.lstm1 = LSTM(32, activation=activation_func, return_sequences=True)
        self.lstm2 = LSTM(16, activation=activation_func)
        
        self.concat_layer = Concatenate()
        self.batch_norm_layer = BatchNormalization()
        
        self.dropout1 = Dropout(0.01)
        self.fully_connected1 = layers.Dense(intermediate_dim, activation=activation_func)
        self.dropout2 = Dropout(0.01)
        
        self.dense_mean = layers.Dense(latent_dim, name="z")

    def call(self, inputs):
        self.inp_seq = inputs[0]
        self.inp_feat = inputs[2]
        self.inp_lap = inputs[1]
        
        x = self.gcn_conv1([self.inp_feat, self.inp_lap])
        
        x = self.flatten_layer(x)

        xx = self.lstm1(self.inp_seq)
        xx = self.lstm2(xx)
        
        x = self.concat_layer([x,xx])
        x = self.batch_norm_layer(x)
        x = self.dropout1(x)
        x = self.fully_connected1(x)
        x = self.dropout2(x)

        z = self.dense_mean(x)

        return z


class Decoder(layers.Layer):
    """Converts z, the encoded digit vector, back into a readable digit."""

    def __init__(self, original_dim, ts_sequence_length, latent_dim=2, intermediate_dim=64, name="decoder", activation_func=tf.nn.tanh, **kwargs):
        super(Decoder, self).__init__(name=name, **kwargs)        
        self.latent_inputs = keras.Input(shape=(latent_dim,))
        self.ts_sequence_length=ts_sequence_length
        
        self.fully_connected_lstm = layers.Dense(self.ts_sequence_length * 2, activation=activation_func)
        self.reshape_layer_lstm = layers.Reshape((self.ts_sequence_length, 2))
        self.lstm_layer1 = LSTM(10, activation=activation_func, return_sequences=True)
        
        self.fully_connected_gcn1 = layers.Dense(160, activation=activation_func)
        self.fully_connected_lap1 = layers.Dense(100, activation=activation_func)
        
        self.reshape_layer_gcn = layers.Reshape((10, 16))
        self.reshape_layer_lap = layers.Reshape((10, 10))
        
        
        self.gcn_layer1 = GCNConv(7, activation=activation_func)

    def call(self, inputs):
        x_lstm = self.fully_connected_lstm(inputs)
        x_lstm = self.reshape_layer_lstm(x_lstm)

        x_lstm = self.lstm_layer1(x_lstm)

        x_lap = self.fully_connected_lap1(inputs)
        x_lap = self.reshape_layer_lap(x_lap)
        
        x_gnn = self.fully_connected_gcn1(inputs)
        x_gnn = self.reshape_layer_gcn(x_gnn)
        x_gnn = self.gcn_layer1([x_gnn, x_lap])
        return x_lstm, x_lap, x_gnn

class VAE(keras.Model):
    def __init__(self, 
                 original_dim,
                 ts_sequence_length,
                 num_ts_features,
                 intermediate_dim=64,
                 latent_dim=2,
                 name="variational-autoencoder",
                 activation_func=tf.nn.tanh,
                 **kwargs):
        super(VAE, self).__init__(name=name, **kwargs)
        self.original_dim = original_dim
        self.encoder = Encoder(ts_sequence_length=ts_sequence_length, num_ts_features=num_ts_features, latent_dim=latent_dim, intermediate_dim=intermediate_dim, activation_func=activation_func)
        self.decoder = Decoder(original_dim, latent_dim=latent_dim, ts_sequence_length=ts_sequence_length, intermediate_dim=intermediate_dim, activation_func=activation_func)
        #self.total_loss_tracker = keras.metrics.Mean(name="total_loss")
        #self.reconstruction_loss_tracker = keras.metrics.Mean(
        #    name="reconstruction_loss"
        #)
        #self.kl_loss_tracker = keras.metrics.Mean(name="kl_loss")

    #@property
    #def metrics(self):
    #    return [
    #        self.total_loss_tracker,
    #        self.reconstruction_loss_tracker,
    #        self.kl_loss_tracker,
    #    ]

    def call(self, inputs):
        #with tf.GradientTape() as tape:
        z = self.encoder(inputs)
        #print(data[0][0])
        reconstruction = self.decoder(z)
        return reconstruction

# %%
y_true = np.array([[0, 1], [0, 0]])
y_true2 = np.array([[0, 1, 2], [0, 0, 2]])

y_pred = np.array([[-18.6, 0.51], [2.94, -12.8]])
y_pred2 = np.array([[-18.6, 0.51, 0.67], [2.94, -12.8, 0.89]])

# Using default 'auto'/'sum_over_batch_size' reduction type.
bce = tf.keras.losses.BinaryCrossentropy(from_logits=True)
bce([y_true, y_true2], [y_pred, y_pred2]).numpy()

# %%
X_train_seq.shape
# Out:
# (34150, 48, 10)

# %%
def get_model():
    vae = VAE(original_dim = 2, latent_dim = 32, ts_sequence_length=sequence_length, num_ts_features=7)
    vae.compile(optimizer=keras.optimizers.Adam(0.001), loss='mse', 
                      metrics=[tf.keras.metrics.RootMeanSquaredError()])
    return vae

# %%
X_valid_seq.shape
# Out:
# (17100, 24, 10)

# %%
### TRAIN A MODEL FOR EACH STORES USING ALL THE DATA AVAILALBE FROM OTHER STORES ###

es = EarlyStopping(patience=5, verbose=1, min_delta=0.001, monitor='val_loss', mode='auto', restore_best_weights=True)

model = get_model()
#print(model.summary())
model.fit([X_train_seq, X_train_lap, X_train_feat], [X_train_seq, X_train_lap, X_train_feat], epochs=100, batch_size=256, 
          validation_data=([X_valid_seq, X_valid_lap, X_valid_feat], [X_valid_seq, X_valid_lap, X_valid_feat]), callbacks=[es], verbose=2)

pred_valid_all = model.predict([X_valid_seq, X_valid_lap, X_valid_feat])
pred_test_all = model.predict([X_test_seq, X_test_lap, X_test_feat])


pred_valid_all_recons = scaler_seq.inverse_transform(pred_valid_all[0].reshape(-1,10)).reshape(pred_valid_all[0].shape)
#reverse_valid = scaler_seq.inverse_transform(y_valid)
pred_test_all_recons = scaler_seq.inverse_transform(pred_test_all[0].reshape(-1,10)).reshape(pred_test_all[0].shape)
#reverse_test = scaler_seq.inverse_transform(y_test)
# Out:
# Epoch 1/100
# 139/139 - 31s - loss: 1.1744 - output_1_loss: 0.7679 - output_2_loss: 0.0623 - output_3_loss: 0.3441 - output_1_root_mean_squared_error: 0.8763 - output_2_root_mean_squared_error: 0.2497 - output_3_root_mean_squared_error: 0.5866 - val_loss: 1.2682 - val_output_1_loss: 0.8299 - val_output_2_loss: 0.0251 - val_output_3_loss: 0.4132 - val_output_1_root_mean_squared_error: 0.9110 - val_output_2_root_mean_squared_error: 0.1584 - val_output_3_root_mean_squared_error: 0.6428 - 31s/epoch - 222ms/step
# Epoch 2/100
# 139/139 - 17s - loss: 0.7863 - output_1_loss: 0.5047 - output_2_loss: 0.0186 - output_3_loss: 0.2630 - output_1_root_mean_squared_error: 0.7104 - output_2_root_mean_squared_error: 0.1364 - output_3_root_mean_squared_error: 0.5128 - val_loss: 1.0611 - val_output_1_loss: 0.6384 - val_output_2_loss: 0.0151 - val_output_3_loss: 0.4076 - val_output_1_root_mean_squared_error: 0.7990 - val_output_2_root_mean_squared_error: 0.1229 - val_output_3_root_mean_squared_error: 0.6384 - 17s/epoch - 121ms/step
# Epoch 3/100
# 139/139 - 17s - loss: 0.6879 - output_1_loss: 0.4187 - output_2_loss: 0.0107 - output_3_loss: 0.2585 - output_1_root_mean_squared_error: 0.6471 - output_2_root_mean_squared_error: 0.1032 - output_3_root_mean_squared_error: 0.5084 - val_loss: 0.9552 - val_output_1_loss: 0.5416 - val_output_2_loss: 0.0099 - val_output_3_loss: 0.4037 - val_output_1_root_mean_squared_error: 0.7360 - val_output_2_root_mean_squared_error: 0.0994 - val_output_3_root_mean_squared_error: 0.6354 - 17s/epoch - 121ms/step
# Epoch 4/100
# 139/139 - 19s - loss: 0.6266 - output_1_loss: 0.3620 - output_2_loss: 0.0080 - output_3_loss: 0.2565 - output_1_root_mean_squared_error: 0.6017 - output_2_root_mean_squared_error: 0.0893 - output_3_root_mean_squared_error: 0.5065 - val_loss: 0.8875 - val_output_1_loss: 0.4833 - val_output_2_loss: 0.0065 - val_output_3_loss: 0.3978 - val_output_1_root_mean_squared_error: 0.6952 - val_output_2_root_mean_squared_error: 0.0803 - val_output_3_root_mean_squared_error: 0.6307 - 19s/epoch - 140ms/step
# Epoch 5/100
# 139/139 - 19s - loss: 0.5904 - output_1_loss: 0.3289 - output_2_loss: 0.0062 - output_3_loss: 0.2553 - output_1_root_mean_squared_error: 0.5735 - output_2_root_mean_squared_error: 0.0789 - output_3_root_mean_squared_error: 0.5053 - val_loss: 0.8518 - val_output_1_loss: 0.4519 - val_output_2_loss: 0.0044 - val_output_3_loss: 0.3955 - val_output_1_root_mean_squared_error: 0.6723 - val_output_2_root_mean_squared_error: 0.0662 - val_output_3_root_mean_squared_error: 0.6289 - 19s/epoch - 140ms/step
# Epoch 6/100
# 139/139 - 20s - loss: 0.5720 - output_1_loss: 0.3122 - output_2_loss: 0.0051 - output_3_loss: 0.2547 - output_1_root_mean_squared_error: 0.5588 - output_2_root_mean_squared_error: 0.0713 - output_3_root_mean_squared_error: 0.5047 - val_loss: 0.8348 - val_output_1_loss: 0.4351 - val_output_2_loss: 0.0037 - val_output_3_loss: 0.3960 - val_output_1_root_mean_squared_error: 0.6596 - val_output_2_root_mean_squared_error: 0.0607 - val_output_3_root_mean_squared_error: 0.6293 - 20s/epoch - 145ms/step
# Epoch 7/100
# 139/139 - 22s - loss: 0.5583 - output_1_loss: 0.2995 - output_2_loss: 0.0045 - output_3_loss: 0.2544 - output_1_root_mean_squared_error: 0.5472 - output_2_root_mean_squared_error: 0.0667 - output_3_root_mean_squared_error: 0.5044 - val_loss: 0.8176 - val_output_1_loss: 0.4205 - val_output_2_loss: 0.0032 - val_output_3_loss: 0.3940 - val_output_1_root_mean_squared_error: 0.6485 - val_output_2_root_mean_squared_error: 0.0561 - val_output_3_root_mean_squared_error: 0.6277 - 22s/epoch - 155ms/step
# Epoch 8/100
# 139/139 - 21s - loss: 0.5472 - output_1_loss: 0.2898 - output_2_loss: 0.0038 - output_3_loss: 0.2536 - output_1_root_mean_squared_error: 0.5383 - output_2_root_mean_squared_error: 0.0615 - output_3_root_mean_squared_error: 0.5036 - val_loss: 0.8058 - val_output_1_loss: 0.4101 - val_output_2_loss: 0.0026 - val_output_3_loss: 0.3931 - val_output_1_root_mean_squared_error: 0.6404 - val_output_2_root_mean_squared_error: 0.0513 - val_output_3_root_mean_squared_error: 0.6269 - 21s/epoch - 148ms/step
# Epoch 9/100
# 139/139 - 20s - loss: 0.5384 - output_1_loss: 0.2817 - output_2_loss: 0.0034 - output_3_loss: 0.2533 - output_1_root_mean_squared_error: 0.5307 - output_2_root_mean_squared_error: 0.0586 - output_3_root_mean_squared_error: 0.5033 - val_loss: 0.8036 - val_output_1_loss: 0.4071 - val_output_2_loss: 0.0027 - val_output_3_loss: 0.3938 - val_output_1_root_mean_squared_error: 0.6381 - val_output_2_root_mean_squared_error: 0.0517 - val_output_3_root_mean_squared_error: 0.6276 - 20s/epoch - 146ms/step
# Epoch 10/100
# 139/139 - 18s - loss: 0.5321 - output_1_loss: 0.2760 - output_2_loss: 0.0031 - output_3_loss: 0.2530 - output_1_root_mean_squared_error: 0.5253 - output_2_root_mean_squared_error: 0.0561 - output_3_root_mean_squared_error: 0.5030 - val_loss: 0.7940 - val_output_1_loss: 0.3979 - val_output_2_loss: 0.0023 - val_output_3_loss: 0.3938 - val_output_1_root_mean_squared_error: 0.6308 - val_output_2_root_mean_squared_error: 0.0483 - val_output_3_root_mean_squared_error: 0.6276 - 18s/epoch - 128ms/step
# Epoch 11/100
# Epoch 22/100
# 139/139 - 17s - loss: 0.4820 - output_1_loss: 0.2287 - output_2_loss: 0.0016 - output_3_loss: 0.2517 - output_1_root_mean_squared_error: 0.4782 - output_2_root_mean_squared_error: 0.0395 - output_3_root_mean_squared_error: 0.5017 - val_loss: 0.7398 - val_output_1_loss: 0.3455 - val_output_2_loss: 0.0014 - val_output_3_loss: 0.3929 - val_output_1_root_mean_squared_error: 0.5878 - val_output_2_root_mean_squared_error: 0.0379 - val_output_3_root_mean_squared_error: 0.6268 - 17s/epoch - 119ms/step
# Epoch 23/100
# 139/139 - 16s - loss: 0.4800 - output_1_loss: 0.2268 - output_2_loss: 0.0015 - output_3_loss: 0.2517 - output_1_root_mean_squared_error: 0.4763 - output_2_root_mean_squared_error: 0.0385 - output_3_root_mean_squared_error: 0.5017 - val_loss: 0.7362 - val_output_1_loss: 0.3425 - val_output_2_loss: 0.0013 - val_output_3_loss: 0.3924 - val_output_1_root_mean_squared_error: 0.5852 - val_output_2_root_mean_squared_error: 0.0354 - val_output_3_root_mean_squared_error: 0.6265 - 16s/epoch - 112ms/step
# Epoch 24/100
# 139/139 - 17s - loss: 0.4777 - output_1_loss: 0.2250 - output_2_loss: 0.0014 - output_3_loss: 0.2513 - output_1_root_mean_squared_error: 0.4744 - output_2_root_mean_squared_error: 0.0372 - output_3_root_mean_squared_error: 0.5013 - val_loss: 0.7346 - val_output_1_loss: 0.3413 - val_output_2_loss: 0.0012 - val_output_3_loss: 0.3921 - val_output_1_root_mean_squared_error: 0.5842 - val_output_2_root_mean_squared_error: 0.0348 - val_output_3_root_mean_squared_error: 0.6262 - 17s/epoch - 119ms/step
# Epoch 25/100
# 139/139 - 16s - loss: 0.4764 - output_1_loss: 0.2237 - output_2_loss: 0.0013 - output_3_loss: 0.2514 - output_1_root_mean_squared_error: 0.4730 - output_2_root_mean_squared_error: 0.0365 - output_3_root_mean_squared_error: 0.5014 - val_loss: 0.7325 - val_output_1_loss: 0.3393 - val_output_2_loss: 0.0012 - val_output_3_loss: 0.3921 - val_output_1_root_mean_squared_error: 0.5825 - val_output_2_root_mean_squared_error: 0.0341 - val_output_3_root_mean_squared_error: 0.6262 - 16s/epoch - 118ms/step
# Epoch 26/100
# 139/139 - 18s - loss: 0.4763 - output_1_loss: 0.2236 - output_2_loss: 0.0014 - output_3_loss: 0.2513 - output_1_root_mean_squared_error: 0.4728 - output_2_root_mean_squared_error: 0.0375 - output_3_root_mean_squared_error: 0.5013 - val_loss: 0.7369 - val_output_1_loss: 0.3413 - val_output_2_loss: 0.0013 - val_output_3_loss: 0.3944 - val_output_1_root_mean_squared_error: 0.5842 - val_output_2_root_mean_squared_error: 0.0354 - val_output_3_root_mean_squared_error: 0.6280 - 18s/epoch - 127ms/step
# Epoch 27/100
-04 - output_3_loss: 0.2507 - output_1_root_mean_squared_error: 0.4492 - output_2_root_mean_squared_error: 0.0273 - output_3_root_mean_squared_error: 0.5007 - val_loss: 0.7106 - val_output_1_loss: 0.3180 - val_output_2_loss: 7.2081e-04 - val_output_3_loss: 0.3919 - val_output_1_root_mean_squared_error: 0.5639 - val_output_2_root_mean_squared_error: 0.0268 - val_output_3_root_mean_squared_error: 0.6260 - 8s/epoch - 54ms/step
# Epoch 55/100
# Restoring model weights from the end of the best epoch: 50.
# 139/139 - 8s - loss: 0.4528 - output_1_loss: 0.2014 - output_2_loss: 7.3119e-04 - output_3_loss: 0.2507 - output_1_root_mean_squared_error: 0.4488 - output_2_root_mean_squared_error: 0.0270 - output_3_root_mean_squared_error: 0.5007 - val_loss: 0.7095 - val_output_1_loss: 0.3170 - val_output_2_loss: 7.1187e-04 - val_output_3_loss: 0.3917 - val_output_1_root_mean_squared_error: 0.5630 - val_output_2_root_mean_squared_error: 0.0267 - val_output_3_root_mean_squared_error: 0.6259 - 8s/epoch - 59ms/step
# Epoch 55: early stopping

# %%
pred_valid_all[0].shape
# Out:
# (17600, 14, 10)

# %%
pred_valid_all_recons = np.resize(pred_valid_all_recons, (np.prod(pred_valid_all_recons.shape[:2]), pred_valid_all_recons.shape[-1]))
pred_valid_all_recons.shape
# Out:
# (410400, 10)

# %%
pred_test_all_recons = np.resize(pred_test_all_recons, (np.prod(pred_test_all_recons.shape[:2]), pred_test_all_recons.shape[-1]))
pred_test_all_recons.shape
# Out:
# (410400, 10)

# %%
X_valid_seq_reshaped = scaler_seq.inverse_transform(X_valid_seq.reshape(-1,10)).reshape(X_valid_seq.shape)

X_valid_seq_reshaped = np.resize(X_valid_seq_reshaped, (np.prod(X_valid_seq_reshaped.shape[:2]), X_valid_seq_reshaped.shape[-1]))
X_valid_seq_reshaped.shape
# Out:
# (410400, 10)

# %%
X_test_seq_reshaped = scaler_seq.inverse_transform(X_test_seq.reshape(-1,10)).reshape(X_test_seq.shape)

X_test_seq_reshaped = np.resize(X_test_seq_reshaped, (np.prod(X_test_seq_reshaped.shape[:2]), X_test_seq_reshaped.shape[-1]))
X_test_seq_reshaped.shape
# Out:
# (410400, 10)

# %%
error = {}

for store in range(10):
    
    error[store] = np.sqrt(mean_squared_error(reverse_test[:,store], pred_test_all[:,store]))

# %%
### PLOT RMSE ###

plt.figure(figsize=(14,5))
plt.bar(range(10), error.values())
plt.xticks(range(10), ['store_'+str(s) for s in range(10)])
plt.ylabel('error')
np.set_printoptions(False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [265], in <cell line: 4>()
#       1 ### PLOT RMSE ###
#       3 plt.figure(figsize=(14,5))
# ----> 4 plt.bar(range(10), error.values())
#       5 plt.xticks(range(10), ['store_'+str(s) for s in range(10)])
#       6 plt.ylabel('error')
#
# NameError: name 'error' is not defined

# %%
fig = plt.figure(figsize=(14,5))
plt.plot(pred_test_all_recons[:2000, 5])
plt.plot(X_test_seq_reshaped[:2000, 5])

plt.ylabel('sales')
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
fig = plt.figure(figsize=(14,5))
plt.plot(pred_valid_all_recons[:400, 5])
plt.plot(X_valid_seq_reshaped[:400, 5])

plt.ylabel('sales')
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
from keras import backend as K
from keras.layers import Activation

def custom_activation(x, beta = 1):
        return (K.sigmoid(beta * x) * x)

    
class Encoder(layers.Layer):
    """Maps MNIST digits to a triplet (z_mean, z_log_var, z)."""

    def __init__(self, ts_sequence_length, num_ts_features, latent_dim=2, intermediate_dim=64, name="encoder", activation_func=tf.nn.tanh, activation_dense_func=tf.nn.tanh, **kwargs):
        super(Encoder, self).__init__(name=name, **kwargs)
        #latent_dim = 2

        self.ts_sequence_length = ts_sequence_length
        self.num_ts_features = num_ts_features
        self.inp_seq = keras.Input((self.ts_sequence_length, 10))
        self.inp_lap = keras.Input((10, 10))
        self.inp_feat = keras.Input((10, self.num_ts_features))

        self.encoder_inputs = [self.inp_seq, self.inp_lap, self.inp_feat]
        
        self.gcn_conv1 = GCNConv(32, activation=activation_func)
        
        self.flatten_layer = layers.Flatten()
        
        self.lstm1 = LSTM(32, activation=activation_func, return_sequences=True)
        self.lstm2 = LSTM(16, activation=activation_func)
        
        self.concat_layer = Concatenate()
        self.batch_norm_layer = BatchNormalization()
        
        self.dropout1 = Dropout(0.01)
        self.fully_connected1 = layers.Dense(intermediate_dim, activation=activation_dense_func)
        self.dropout2 = Dropout(0.01)
        
        self.dense_mean = layers.Dense(latent_dim, name="z")

    def call(self, inputs):
        self.inp_seq = inputs[0]
        self.inp_feat = inputs[2]
        self.inp_lap = inputs[1]
        
        x = self.gcn_conv1([self.inp_feat, self.inp_lap])
        
        x = self.flatten_layer(x)

        xx = self.lstm1(self.inp_seq)
        xx = self.lstm2(xx)
        
        x = self.concat_layer([x,xx])
        x = self.batch_norm_layer(x)
        x = self.dropout1(x)
        x = self.fully_connected1(x)
        x = self.dropout2(x)

        z = self.dense_mean(x)

        return z


class Decoder(layers.Layer):
    """Converts z, the encoded digit vector, back into a readable digit."""

    def __init__(self, original_dim, ts_sequence_length, latent_dim=2, intermediate_dim=64, name="decoder", activation_func=tf.nn.tanh, activation_dense_func=tf.nn.tanh, **kwargs):
        super(Decoder, self).__init__(name=name, **kwargs)        
        self.latent_inputs = keras.Input(shape=(latent_dim,))
        self.ts_sequence_length=ts_sequence_length
        
        self.fully_connected_lstm = layers.Dense(self.ts_sequence_length * 2, activation=activation_dense_func)
        self.reshape_layer_lstm = layers.Reshape((self.ts_sequence_length, 2))
        self.lstm_layer1 = LSTM(10, activation=activation_func, return_sequences=True)
        
        self.fully_connected_gcn1 = layers.Dense(160, activation=activation_dense_func)
        self.fully_connected_lap1 = layers.Dense(100, activation=activation_dense_func)
        
        self.reshape_layer_gcn = layers.Reshape((10, 16))
        self.reshape_layer_lap = layers.Reshape((10, 10))
        
        
        self.gcn_layer1 = GCNConv(7, activation=activation_func)

    def call(self, inputs):
        x_lstm = self.fully_connected_lstm(inputs)
        x_lstm = self.reshape_layer_lstm(x_lstm)

        x_lstm = self.lstm_layer1(x_lstm)

        x_lap = self.fully_connected_lap1(inputs)
        x_lap = self.reshape_layer_lap(x_lap)
        
        x_gnn = self.fully_connected_gcn1(inputs)
        x_gnn = self.reshape_layer_gcn(x_gnn)
        x_gnn = self.gcn_layer1([x_gnn, x_lap])
        return x_lstm, x_lap, x_gnn

class VAE(keras.Model):
    def __init__(self, 
                 original_dim,
                 ts_sequence_length,
                 num_ts_features,
                 intermediate_dim=64,
                 latent_dim=2,
                 name="variational-autoencoder",
                 activation_func=tf.nn.tanh,
                 activation_dense_func=tf.nn.tanh,
                 **kwargs):
        super(VAE, self).__init__(name=name, **kwargs)
        self.original_dim = original_dim
        self.encoder = Encoder(ts_sequence_length=ts_sequence_length, num_ts_features=num_ts_features, latent_dim=latent_dim, intermediate_dim=intermediate_dim, activation_func=activation_func, activation_dense_func=activation_dense_func)
        self.decoder = Decoder(original_dim, latent_dim=latent_dim, ts_sequence_length=ts_sequence_length, intermediate_dim=intermediate_dim, activation_func=activation_func, activation_dense_func=activation_dense_func)
        #self.total_loss_tracker = keras.metrics.Mean(name="total_loss")
        #self.reconstruction_loss_tracker = keras.metrics.Mean(
        #    name="reconstruction_loss"
        #)
        #self.kl_loss_tracker = keras.metrics.Mean(name="kl_loss")

    #@property
    #def metrics(self):
    #    return [
    #        self.total_loss_tracker,
    #        self.reconstruction_loss_tracker,
    #        self.kl_loss_tracker,
    #    ]

    def call(self, inputs):
        #with tf.GradientTape() as tape:
        z = self.encoder(inputs)
        #print(data[0][0])
        reconstruction = self.decoder(z)
        return reconstruction

# %%
def get_model():
    vae = VAE(original_dim = 2, latent_dim = 32, ts_sequence_length=sequence_length, num_ts_features=7, activation_func=custom_activation, activation_dense_func=tf.nn.relu)
    vae.compile(optimizer=keras.optimizers.Adam(0.001), loss='mse', 
                      metrics=[tf.keras.metrics.RootMeanSquaredError()])
    return vae

# %%
X_valid_seq.shape
# Out:
# (17100, 24, 10)

# %%
### TRAIN A MODEL FOR EACH STORES USING ALL THE DATA AVAILALBE FROM OTHER STORES ###

es = EarlyStopping(patience=5, verbose=1, min_delta=0.001, monitor='val_loss', mode='auto', restore_best_weights=True)

model = get_model()
#print(model.summary())
model.fit([X_train_seq, X_train_lap, X_train_feat], [X_train_seq, X_train_lap, X_train_feat], epochs=100, batch_size=256, 
          validation_data=([X_valid_seq, X_valid_lap, X_valid_feat], [X_valid_seq, X_valid_lap, X_valid_feat]), callbacks=[es], verbose=2)

pred_valid_all = model.predict([X_valid_seq, X_valid_lap, X_valid_feat])
pred_test_all = model.predict([X_test_seq, X_test_lap, X_test_feat])


pred_valid_all_recons = scaler_seq.inverse_transform(pred_valid_all[0].reshape(-1,10)).reshape(pred_valid_all[0].shape)
#reverse_valid = scaler_seq.inverse_transform(y_valid)
pred_test_all_recons = scaler_seq.inverse_transform(pred_test_all[0].reshape(-1,10)).reshape(pred_test_all[0].shape)
#reverse_test = scaler_seq.inverse_transform(y_test)
# Out:
# Epoch 1/100
# 139/139 - 10s - loss: 0.0806 - output_1_loss: 0.0577 - output_2_loss: 0.0092 - output_3_loss: 0.0136 - output_1_root_mean_squared_error: 0.2403 - output_2_root_mean_squared_error: 0.0961 - output_3_root_mean_squared_error: 0.1167 - val_loss: 0.1056 - val_output_1_loss: 0.0737 - val_output_2_loss: 0.0041 - val_output_3_loss: 0.0278 - val_output_1_root_mean_squared_error: 0.2715 - val_output_2_root_mean_squared_error: 0.0638 - val_output_3_root_mean_squared_error: 0.1668 - 10s/epoch - 74ms/step
# Epoch 2/100
# 139/139 - 4s - loss: 0.0175 - output_1_loss: 0.0116 - output_2_loss: 0.0042 - output_3_loss: 0.0018 - output_1_root_mean_squared_error: 0.1075 - output_2_root_mean_squared_error: 0.0648 - output_3_root_mean_squared_error: 0.0419 - val_loss: 0.0693 - val_output_1_loss: 0.0492 - val_output_2_loss: 0.0026 - val_output_3_loss: 0.0175 - val_output_1_root_mean_squared_error: 0.2218 - val_output_2_root_mean_squared_error: 0.0511 - val_output_3_root_mean_squared_error: 0.1323 - 4s/epoch - 32ms/step
# Epoch 3/100
# 139/139 - 4s - loss: 0.0121 - output_1_loss: 0.0081 - output_2_loss: 0.0029 - output_3_loss: 0.0011 - output_1_root_mean_squared_error: 0.0901 - output_2_root_mean_squared_error: 0.0541 - output_3_root_mean_squared_error: 0.0333 - val_loss: 0.0519 - val_output_1_loss: 0.0371 - val_output_2_loss: 0.0022 - val_output_3_loss: 0.0126 - val_output_1_root_mean_squared_error: 0.1925 - val_output_2_root_mean_squared_error: 0.0467 - val_output_3_root_mean_squared_error: 0.1122 - 4s/epoch - 32ms/step
# Epoch 4/100
# 139/139 - 4s - loss: 0.0098 - output_1_loss: 0.0066 - output_2_loss: 0.0023 - output_3_loss: 9.1463e-04 - output_1_root_mean_squared_error: 0.0811 - output_2_root_mean_squared_error: 0.0484 - output_3_root_mean_squared_error: 0.0302 - val_loss: 0.0261 - val_output_1_loss: 0.0184 - val_output_2_loss: 0.0017 - val_output_3_loss: 0.0060 - val_output_1_root_mean_squared_error: 0.1355 - val_output_2_root_mean_squared_error: 0.0418 - val_output_3_root_mean_squared_error: 0.0774 - 4s/epoch - 32ms/step
# Epoch 5/100
# 139/139 - 4s - loss: 0.0084 - output_1_loss: 0.0056 - output_2_loss: 0.0020 - output_3_loss: 7.6502e-04 - output_1_root_mean_squared_error: 0.0749 - output_2_root_mean_squared_error: 0.0445 - output_3_root_mean_squared_error: 0.0277 - val_loss: 0.0124 - val_output_1_loss: 0.0082 - val_output_2_loss: 0.0017 - val_output_3_loss: 0.0025 - val_output_1_root_mean_squared_error: 0.0908 - val_output_2_root_mean_squared_error: 0.0407 - val_output_3_root_mean_squared_error: 0.0496 - 4s/epoch - 32ms/step
# Epoch 6/100
# 139/139 - 4s - loss: 0.0077 - output_1_loss: 0.0052 - output_2_loss: 0.0018 - output_3_loss: 6.4823e-04 - output_1_root_mean_squared_error: 0.0723 - output_2_root_mean_squared_error: 0.0423 - output_3_root_mean_squared_error: 0.0255 - val_loss: 0.0078 - val_output_1_loss: 0.0057 - val_output_2_loss: 0.0016 - val_output_3_loss: 5.2700e-04 - val_output_1_root_mean_squared_error: 0.0758 - val_output_2_root_mean_squared_error: 0.0394 - val_output_3_root_mean_squared_error: 0.0230 - 4s/epoch - 32ms/step
# Epoch 7/100
# 139/139 - 5s - loss: 0.0072 - output_1_loss: 0.0050 - output_2_loss: 0.0016 - output_3_loss: 5.1731e-04 - output_1_root_mean_squared_error: 0.0710 - output_2_root_mean_squared_error: 0.0400 - output_3_root_mean_squared_error: 0.0227 - val_loss: 0.0080 - val_output_1_loss: 0.0057 - val_output_2_loss: 0.0015 - val_output_3_loss: 7.3922e-04 - val_output_1_root_mean_squared_error: 0.0756 - val_output_2_root_mean_squared_error: 0.0387 - val_output_3_root_mean_squared_error: 0.0272 - 5s/epoch - 33ms/step
# Epoch 8/100
# 139/139 - 5s - loss: 0.0068 - output_1_loss: 0.0049 - output_2_loss: 0.0014 - output_3_loss: 4.3467e-04 - output_1_root_mean_squared_error: 0.0702 - output_2_root_mean_squared_error: 0.0381 - output_3_root_mean_squared_error: 0.0208 - val_loss: 0.0075 - val_output_1_loss: 0.0057 - val_output_2_loss: 0.0014 - val_output_3_loss: 4.3177e-04 - val_output_1_root_mean_squared_error: 0.0755 - val_output_2_root_mean_squared_error: 0.0371 - val_output_3_root_mean_squared_error: 0.0208 - 5s/epoch - 33ms/step
# Epoch 9/100
# 139/139 - 5s - loss: 0.0067 - output_1_loss: 0.0049 - output_2_loss: 0.0013 - output_3_loss: 4.3071e-04 - output_1_root_mean_squared_error: 0.0702 - output_2_root_mean_squared_error: 0.0366 - output_3_root_mean_squared_error: 0.0208 - val_loss: 0.0071 - val_output_1_loss: 0.0055 - val_output_2_loss: 0.0012 - val_output_3_loss: 4.2680e-04 - val_output_1_root_mean_squared_error: 0.0742 - val_output_2_root_mean_squared_error: 0.0345 - val_output_3_root_mean_squared_error: 0.0207 - 5s/epoch - 33ms/step
# Epoch 10/100
# 139/139 - 5s - loss: 0.0066 - output_1_loss: 0.0049 - output_2_loss: 0.0013 - output_3_loss: 4.4377e-04 - output_1_root_mean_squared_error: 0.0700 - output_2_root_mean_squared_error: 0.0354 - output_3_root_mean_squared_error: 0.0211 - val_loss: 0.0093 - val_output_1_loss: 0.0064 - val_output_2_loss: 0.0012 - val_output_3_loss: 0.0017 - val_output_1_root_mean_squared_error: 0.0801 - val_output_2_root_mean_squared_error: 0.0345 - val_output_3_root_mean_squared_error: 0.0414 - 5s/epoch - 33ms/step
# Epoch 11/100
# Restoring model weights from the end of the best epoch: 6.
# 139/139 - 5s - loss: 0.0065 - output_1_loss: 0.0048 - output_2_loss: 0.0012 - output_3_loss: 4.5488e-04 - output_1_root_mean_squared_error: 0.0696 - output_2_root_mean_squared_error: 0.0348 - output_3_root_mean_squared_error: 0.0213 - val_loss: 0.0068 - val_output_1_loss: 0.0055 - val_output_2_loss: 0.0011 - val_output_3_loss: 2.4162e-04 - val_output_1_root_mean_squared_error: 0.0741 - val_output_2_root_mean_squared_error: 0.0333 - val_output_3_root_mean_squared_error: 0.0155 - 5s/epoch - 33ms/step
# Epoch 11: early stopping

# %%
model.summary()
# Out:
# Model: "variational-autoencoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  encoder (Encoder)           multiple                  33888
#
#  decoder (Decoder)           multiple                  10803
#
# =================================================================
# Total params: 44,691
# Trainable params: 44,019
# Non-trainable params: 672
# _________________________________________________________________

# %%
pred_valid_all[0].shape
# Out:
# (17100, 24, 10)

# %%
pred_valid_all_recons = np.resize(pred_valid_all_recons, (np.prod(pred_valid_all_recons.shape[:2]), pred_valid_all_recons.shape[-1]))
pred_valid_all_recons.shape
# Out:
# (410400, 10)

# %%
pred_test_all_recons = np.resize(pred_test_all_recons, (np.prod(pred_test_all_recons.shape[:2]), pred_test_all_recons.shape[-1]))
pred_test_all_recons.shape
# Out:
# (410400, 10)

# %%
X_valid_seq_reshaped = scaler_seq.inverse_transform(X_valid_seq.reshape(-1,10)).reshape(X_valid_seq.shape)

X_valid_seq_reshaped = np.resize(X_valid_seq_reshaped, (np.prod(X_valid_seq_reshaped.shape[:2]), X_valid_seq_reshaped.shape[-1]))
X_valid_seq_reshaped.shape
# Out:
# (410400, 10)

# %%
X_test_seq_reshaped = scaler_seq.inverse_transform(X_test_seq.reshape(-1,10)).reshape(X_test_seq.shape)

X_test_seq_reshaped = np.resize(X_test_seq_reshaped, (np.prod(X_test_seq_reshaped.shape[:2]), X_test_seq_reshaped.shape[-1]))
X_test_seq_reshaped.shape
# Out:
# (410400, 10)

# %%
error = {}

for store in range(10):
    
    error[store] = np.sqrt(mean_squared_error(reverse_test[:,store], pred_test_all[:,store]))

# %%
### PLOT RMSE ###

plt.figure(figsize=(14,5))
plt.bar(range(10), error.values())
plt.xticks(range(10), ['store_'+str(s) for s in range(10)])
plt.ylabel('error')
np.set_printoptions(False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [265], in <cell line: 4>()
#       1 ### PLOT RMSE ###
#       3 plt.figure(figsize=(14,5))
# ----> 4 plt.bar(range(10), error.values())
#       5 plt.xticks(range(10), ['store_'+str(s) for s in range(10)])
#       6 plt.ylabel('error')
#
# NameError: name 'error' is not defined

# %%
fig = plt.figure(figsize=(14,5))
plt.plot(pred_test_all_recons[:2000, 5])
plt.plot(X_test_seq_reshaped[:2000, 5])

plt.ylabel('sales')
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
fig = plt.figure(figsize=(14,5))
plt.plot(pred_valid_all_recons[100:200, 5])
plt.plot(X_valid_seq_reshaped[100:200, 5])

plt.ylabel('sales')
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
from keras import backend as K
from keras.layers import Activation

def custom_activation(x, beta = 1):
        return (K.sigmoid(beta * x) * x)

    
class Encoder(layers.Layer):
    """Maps MNIST digits to a triplet (z_mean, z_log_var, z)."""

    def __init__(self, ts_sequence_length, num_ts_features, latent_dim=2, intermediate_dim=64, nr_shared=2, name="encoder", activation_func=tf.nn.tanh, activation_dense_func=tf.nn.tanh, **kwargs):
        super(Encoder, self).__init__(name=name, **kwargs)
        #latent_dim = 2

        self.ts_sequence_length = ts_sequence_length
        self.num_ts_features = num_ts_features
        self.inp_seq = keras.Input((self.ts_sequence_length, 10))
        self.inp_lap = keras.Input((10, 10))
        self.inp_feat = keras.Input((10, self.num_ts_features))

        self.encoder_inputs = [self.inp_seq, self.inp_lap, self.inp_feat]
        
        self.gcn_conv1 = GCNConv(32, activation=activation_func)
        
        self.flatten_layer = layers.Flatten()
        
        self.lstm1 = LSTM(32, activation=activation_func, return_sequences=True)
        self.lstm2 = LSTM(16, activation=activation_func)
        
        self.concat_layer = Concatenate()
        self.batch_norm_layer = BatchNormalization()
        
        self.dropout1 = Dropout(0.01)
        self.fully_connected1 = layers.Dense(intermediate_dim, activation=activation_dense_func)
        self.dropout2 = Dropout(0.01)
        
        self.hidden_shared_layer1 = Dense(nr_shared, activation=activation_dense_func)
        self.hidden_unshared_layer1 = Dense(latent_dim-nr_shared, activation=activation_dense_func)

        
    def call(self, inputs):
        self.inp_seq = inputs[0]
        self.inp_feat = inputs[2]
        self.inp_lap = inputs[1]
        
        x = self.gcn_conv1([self.inp_feat, self.inp_lap])
        
        x = self.flatten_layer(x)

        xx = self.lstm1(self.inp_seq)
        xx = self.lstm2(xx)
        
        x = self.concat_layer([x,xx])
        x = self.batch_norm_layer(x)
        x = self.dropout1(x)
        x = self.fully_connected1(x)
        x = self.dropout2(x)
        
        z_shared = self.hidden_shared_layer1(x)
        z_unshared = self.hidden_unshared_layer1(x)
        
        #z = self.dense_mean(x)
        z = tf.concat([z_shared,z_unshared],-1)

        return z


class Decoder(layers.Layer):
    """Converts z, the encoded digit vector, back into a readable digit."""

    def __init__(self, original_dim, ts_sequence_length, latent_dim=2, intermediate_dim=64, name="decoder", activation_func=tf.nn.tanh, activation_dense_func=tf.nn.tanh, **kwargs):
        super(Decoder, self).__init__(name=name, **kwargs)        
        self.latent_inputs = keras.Input(shape=(nr_ae, latent_dim,))
        
        # split nr_ae into separate tensors
        self.ts_sequence_length=ts_sequence_length
        
        # apply same layers to each split up nr_ae input tensors - use for loop
        self.fully_connected_lstm = layers.Dense(self.ts_sequence_length * 2, activation=activation_dense_func)
        self.reshape_layer_lstm = layers.Reshape((self.ts_sequence_length, 2))
        self.lstm_layer1 = LSTM(10, activation=activation_func, return_sequences=True) # Dense layers in Keras
        
        self.fully_connected_gcn1 = layers.Dense(160, activation=activation_dense_func)
        self.fully_connected_lap1 = layers.Dense(100, activation=activation_dense_func)
        
        self.reshape_layer_gcn = layers.Reshape((10, 16))
        self.reshape_layer_lap = layers.Reshape((10, 10))
        
        # stick nr_ae together
        self.gcn_layer1 = GCNConv(7, activation=activation_func)

    def call(self, inputs):
        x_lstm = self.fully_connected_lstm(inputs)
        x_lstm = self.reshape_layer_lstm(x_lstm)

        x_lstm = self.lstm_layer1(x_lstm)

        x_lap = self.fully_connected_lap1(inputs)
        x_lap = self.reshape_layer_lap(x_lap)
        
        x_gnn = self.fully_connected_gcn1(inputs)
        x_gnn = self.reshape_layer_gcn(x_gnn)
        x_gnn = self.gcn_layer1([x_gnn, x_lap])
        return x_lstm, x_lap, x_gnn

class VAE(keras.Model):
    def __init__(self, 
                 original_dim,
                 ts_sequence_length,
                 num_ts_features,
                 intermediate_dim=64,
                 latent_dim=2,
                 name="variational-autoencoder",
                 activation_func=tf.nn.tanh,
                 activation_dense_func=tf.nn.tanh,
                 **kwargs):
        super(VAE, self).__init__(name=name, **kwargs)
        self.original_dim = original_dim
        self.encoder = Encoder(ts_sequence_length=ts_sequence_length, num_ts_features=num_ts_features, latent_dim=latent_dim, intermediate_dim=intermediate_dim, activation_func=activation_func, activation_dense_func=activation_dense_func)
        self.decoder = Decoder(original_dim, latent_dim=latent_dim, ts_sequence_length=ts_sequence_length, intermediate_dim=intermediate_dim, activation_func=activation_func, activation_dense_func=activation_dense_func)
        #self.total_loss_tracker = keras.metrics.Mean(name="total_loss")
        #self.reconstruction_loss_tracker = keras.metrics.Mean(
        #    name="reconstruction_loss"
        #)
        #self.kl_loss_tracker = keras.metrics.Mean(name="kl_loss")

    #@property
    #def metrics(self):
    #    return [
    #        self.total_loss_tracker,
    #        self.reconstruction_loss_tracker,
    #        self.kl_loss_tracker,
    #    ]

    def call(self, inputs):
        #with tf.GradientTape() as tape:
        z = self.encoder(inputs)
        #print(data[0][0])
        reconstruction = self.decoder(z)
        
        square_diff2 = K.square(z_shared[1:,:]-z_shared[:nr_ae-1,:])
        shared_loss = tf.reduce_mean(square_diff2)
        self.add_loss(shared_loss)

        return reconstruction

# %%
def get_model():
    vae = VAE(original_dim = 2, latent_dim = 32, ts_sequence_length=sequence_length, num_ts_features=7, activation_func=custom_activation, activation_dense_func=tf.nn.relu)
    vae.compile(optimizer=keras.optimizers.Adam(0.001), loss='mse', 
                      metrics=[tf.keras.metrics.RootMeanSquaredError()])
    return vae
